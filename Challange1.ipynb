# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("data/auto_mpg.csv",header=0,names=['MPG','Cyliners','Displacement','HorsePower','Weight','Accelaration','Model Year','Origin'])
df.head(10)
# Out:
#     MPG  Cyliners  Displacement  HorsePower  Weight  Accelaration  Model Year  \
# 0  18.0         8         307.0       130.0  3504.0          12.0          70
# 1  15.0         8         350.0       165.0  3693.0          11.5          70
# 2  18.0         8         318.0       150.0  3436.0          11.0          70
# 3  16.0         8         304.0       150.0  3433.0          12.0          70
# 4  17.0         8         302.0       140.0  3449.0          10.5          70
# 5  15.0         8         429.0       198.0  4341.0          10.0          70
# 6  14.0         8         454.0       220.0  4354.0           9.0          70
# 7  14.0         8         440.0       215.0  4312.0           8.5          70
# 8  14.0         8         455.0       225.0  4425.0          10.0          70
# 9  15.0         8         390.0       190.0  3850.0           8.5          70
#
#   Origin
# 0  India
# 1  India
# 2  India
# 3  India
# 4  India
# 5  India
# 6  India
# 7  India
# 8  India
# ...

# %%
df.shape
# Out:
# (398, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           398 non-null    float64
#  1   Cyliners      398 non-null    int64
#  2   Displacement  398 non-null    float64
#  3   HorsePower    392 non-null    float64
#  4   Weight        398 non-null    float64
#  5   Accelaration  398 non-null    float64
#  6   Model Year    398 non-null    int64
#  7   Origin        398 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 25.0+ KB

# %%
list(df.columns)
# Out:
# ['MPG',
#  'Cyliners',
#  'Displacement',
#  'HorsePower',
#  'Weight',
#  'Accelaration',
#  'Model Year',
#  'Origin']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.describe()
# Out:
#               MPG    Cyliners  Displacement  HorsePower       Weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        Accelaration  Model Year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.describe(include=object)
# Out:
#        Origin
# count     398
# unique      3
# top     India
# freq      249

# %%
df["Origin"].value_counts()
# Out:
# Origin
# India      249
# Germany     79
# USA         70
# Name: count, dtype: int64

# %%
pt= df["Origin"].value_counts()
pt.plot(kind="bar")
# Out:
# <Axes: xlabel='Origin'>

# %%
df["Displacement on power"]= df["Displacement"]/df["HorsePower"]
df
# Out:
#       MPG  Cyliners  Displacement  HorsePower  Weight  Accelaration  \
# 0    18.0         8         307.0       130.0  3504.0          12.0
# 1    15.0         8         350.0       165.0  3693.0          11.5
# 2    18.0         8         318.0       150.0  3436.0          11.0
# 3    16.0         8         304.0       150.0  3433.0          12.0
# 4    17.0         8         302.0       140.0  3449.0          10.5
# ..    ...       ...           ...         ...     ...           ...
# 393  27.0         4         140.0        86.0  2790.0          15.6
# 394  44.0         4          97.0        52.0  2130.0          24.6
# 395  32.0         4         135.0        84.0  2295.0          11.6
# 396  28.0         4         120.0        79.0  2625.0          18.6
# 397  31.0         4         119.0        82.0  2720.0          19.4
#
#      Model Year Origin  Displacement on power
# 0            70  India               2.361538
# 1            70  India               2.121212
# ...

# %%
df["Weight_per_cyliner"]= df["Weight"]/df["Cyliners"]
df["acc_per_cyl"]= df["Accelaration"]/df["Cyliners"]
df
# Out:
#       MPG  Cyliners  Displacement  HorsePower  Weight  Accelaration  \
# 0    18.0         8         307.0       130.0  3504.0          12.0
# 1    15.0         8         350.0       165.0  3693.0          11.5
# 2    18.0         8         318.0       150.0  3436.0          11.0
# 3    16.0         8         304.0       150.0  3433.0          12.0
# 4    17.0         8         302.0       140.0  3449.0          10.5
# ..    ...       ...           ...         ...     ...           ...
# 393  27.0         4         140.0        86.0  2790.0          15.6
# 394  44.0         4          97.0        52.0  2130.0          24.6
# 395  32.0         4         135.0        84.0  2295.0          11.6
# 396  28.0         4         120.0        79.0  2625.0          18.6
# 397  31.0         4         119.0        82.0  2720.0          19.4
#
#      Model Year Origin  Displacement on power  Weight_per_cyliner  acc_per_cyl
# ...

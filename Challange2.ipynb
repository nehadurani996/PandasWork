# %%
import pandas as pd
import csv

# %%
df= pd.read_csv("data/marketing_campaign.csv",sep="\t")
df[["MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds"]]
# Out:
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# 0          635         88              546              172                88
# 1           11          1                6                2                 1
# 2          426         49              127              111                21
# 3           11          4               20               10                 3
# 4          173         43              118               46                27
# ...        ...        ...              ...              ...               ...
# 2235       709         43              182               42               118
# 2236       406          0               30                0                 0
# 2237       908         48              217               32                12
# 2238       428         30              214               80                30
# 2239        84          3               61                2                 1
#
#       MntGoldProds
# 0               88
# 1                6
# 2               42
# 3                5
# 4               15
# ...            ...
# 2235           247
# 2236             8
# 2237            24
# 2238            61
# 2239            21
#
# [2240 rows x 6 columns]

# %%
df.set_index("ID",inplace=True)
df.loc[7446:2114,"MntWines":"MntGoldProds"]
# Out:
#       MntWines  MntFruits  MntMeatProducts  MntFishProducts  MntSweetProducts  \
# ID
# 7446       520         42               98                0                42
# 965        235         65              164               50                49
# 6177        76         10               56                3                 1
# 4855        14          0               24                3                 3
# 5899        28          0                6                1                 1
# 1994         5          5                6                0                 2
# 387          6         16               11               11                 1
# 2125       194         61              480              225               112
# 8180       233          2               53                3                 5
# 2569         3         14               17                6                 1
# 2114      1006         22              115               59                68
#
#       MntGoldProds
# ID
# 7446            14
# 965             27
# 6177            23
# 4855             2
# 5899            13
# 1994             1
# 387             16
# 2125            30
# 8180            14
# 2569             5
# 2114            45

# %%
df.reset_index(inplace=True)

# %%
df.iloc[50:301:2,-9] #stepsize 2 is for alternate rows
# Out:
# 50     0
# 52     0
# 54     0
# 56     0
# 58     0
#       ..
# 292    0
# 294    0
# 296    0
# 298    0
# 300    0
# Name: AcceptedCmp3, Length: 126, dtype: int64
